# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as sns       #data visualizer
# %matplotlib inline
import warnings                        # To ignore any warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("cereal.csv")
df
# Out:
#                   Cereal Name mfr   type  calories  protien  fat  sodium  \
# 0                   100% Bran    N  cold        70        4    1     130
# 1          100 % Natural Bran    Q  cold       120        3    5      15
# 2                    All-Bran    K  cold        70        4    1     260
# 3   All Bran with Extra Fiber    K  cold        50        4    0     140
# 4              Almond Delight    R  cold       110        2    2     200
# 5     Apple Cinnamon Cheerios    G  cold       110        2    2     180
# 6                 Apple Jacks    K  cold       110        2    0     125
# 7                     Basic 4    G  cold       130        3    2     210
# 8                   Bran Chex    R  cold        90        2    1     200
# 9                 Bran Flakes    P  cold        90        3    0     210
# 10               Cap’n’Crunch    Q  cold       120        1    2     220
# 11                   Cheerios    G  cold       110        6    2     290
# ...

# %%
df.shape
# Out:
# (20, 16)

# %%
sns.boxplot(df['type'],df['calories'])

# %%
sns.boxplot(df['shelf'],df['rating'])

# %%
df.corr()
# Out:
#           calories   protien       fat    sodium     fiber     carbo  \
# calories  1.000000 -0.444594  0.478380 -0.023867 -0.912518  0.452598
# protien  -0.444594  1.000000  0.091186  0.121220  0.606809 -0.176188
# fat       0.478380  0.091186  1.000000 -0.353765 -0.222564 -0.250628
# sodium   -0.023867  0.121220 -0.353765  1.000000 -0.135483  0.625861
# fiber    -0.912518  0.606809 -0.222564 -0.135483  1.000000 -0.567574
# carbo     0.452598 -0.176188 -0.250628  0.625861 -0.567574  1.000000
# sugar     0.528478 -0.706675  0.140788 -0.417858 -0.543755 -0.241484
# potass   -0.833878  0.660241 -0.036440 -0.113723  0.954138 -0.621041
# vitamins -0.202481 -0.089300 -0.644917  0.576658  0.059863  0.254884
# shelf    -0.230061  0.239566  0.259519 -0.486464  0.471077 -0.584652
# weight    0.321588  0.089300  0.107486  0.086754 -0.059863  0.284553
# cups      0.579304 -0.237194 -0.018907  0.123130 -0.698629  0.562574
# rating   -0.882001  0.703093 -0.374251  0.018391  0.916807 -0.252634
#
# ...

# %%
df.corr()['rating'].sort_values()
# Out:
# calories   -0.882001
# sugar      -0.759166
# cups       -0.482326
# fat        -0.374251
# carbo      -0.252634
# weight     -0.058047
# sodium      0.018391
# vitamins    0.097899
# shelf       0.274547
# protien     0.703093
# potass      0.826072
# fiber       0.916807
# rating      1.000000
# Name: rating, dtype: float64

# %%
df.corr()['calories'].sort_values()
# Out:
# fiber      -0.912518
# rating     -0.882001
# potass     -0.833878
# protien    -0.444594
# shelf      -0.230061
# vitamins   -0.202481
# sodium     -0.023867
# weight      0.321588
# carbo       0.452598
# fat         0.478380
# sugar       0.528478
# cups        0.579304
# calories    1.000000
# Name: calories, dtype: float64

# %%
df.corr()['protien'].sort_values()
# Out:
# sugar      -0.706675
# calories   -0.444594
# cups       -0.237194
# carbo      -0.176188
# vitamins   -0.089300
# weight      0.089300
# fat         0.091186
# sodium      0.121220
# shelf       0.239566
# fiber       0.606809
# potass      0.660241
# rating      0.703093
# protien     1.000000
# Name: protien, dtype: float64

# %%
df.corr()['fat'].sort_values()
# Out:
# vitamins   -0.644917
# rating     -0.374251
# sodium     -0.353765
# carbo      -0.250628
# fiber      -0.222564
# potass     -0.036440
# cups       -0.018907
# protien     0.091186
# weight      0.107486
# sugar       0.140788
# shelf       0.259519
# calories    0.478380
# fat         1.000000
# Name: fat, dtype: float64

# %%
df.corr()['sodium'].sort_values()
# Out:
# shelf      -0.486464
# sugar      -0.417858
# fat        -0.353765
# fiber      -0.135483
# potass     -0.113723
# calories   -0.023867
# rating      0.018391
# weight      0.086754
# protien     0.121220
# cups        0.123130
# vitamins    0.576658
# carbo       0.625861
# sodium      1.000000
# Name: sodium, dtype: float64

# %%
df.corr()['fiber'].sort_values()
# Out:
# calories   -0.912518
# cups       -0.698629
# carbo      -0.567574
# sugar      -0.543755
# fat        -0.222564
# sodium     -0.135483
# weight     -0.059863
# vitamins    0.059863
# shelf       0.471077
# protien     0.606809
# rating      0.916807
# potass      0.954138
# fiber       1.000000
# Name: fiber, dtype: float64

# %%
df.corr()['carbo'].sort_values()
# Out:
# potass     -0.621041
# shelf      -0.584652
# fiber      -0.567574
# rating     -0.252634
# fat        -0.250628
# sugar      -0.241484
# protien    -0.176188
# vitamins    0.254884
# weight      0.284553
# calories    0.452598
# cups        0.562574
# sodium      0.625861
# carbo       1.000000
# Name: carbo, dtype: float64

# %%
df.corr()['sugar'].sort_values()
# Out:
# rating     -0.759166
# protien    -0.706675
# fiber      -0.543755
# potass     -0.515401
# sodium     -0.417858
# carbo      -0.241484
# vitamins   -0.031597
# weight      0.031597
# shelf       0.033906
# fat         0.140788
# cups        0.203370
# calories    0.528478
# sugar       1.000000
# Name: sugar, dtype: float64

# %%
df.corr()['potass'].sort_values()
# Out:
# calories   -0.833878
# cups       -0.737368
# carbo      -0.621041
# sugar      -0.515401
# sodium     -0.113723
# vitamins   -0.043412
# weight     -0.042764
# fat        -0.036440
# shelf       0.614754
# protien     0.660241
# rating      0.826072
# fiber       0.954138
# potass      1.000000
# Name: potass, dtype: float64

# %%
df.corr()['vitamins'].sort_values()
# Out:
# fat        -0.644917
# shelf      -0.225913
# cups       -0.208307
# calories   -0.202481
# protien    -0.089300
# potass     -0.043412
# sugar      -0.031597
# weight      0.052632
# fiber       0.059863
# rating      0.097899
# carbo       0.254884
# sodium      0.576658
# vitamins    1.000000
# Name: vitamins, dtype: float64

# %%
df.corr()['shelf'].sort_values()
# Out:
# cups       -0.606019
# carbo      -0.584652
# sodium     -0.486464
# calories   -0.230061
# vitamins   -0.225913
# sugar       0.033906
# weight      0.225913
# protien     0.239566
# fat         0.259519
# rating      0.274547
# fiber       0.471077
# potass      0.614754
# shelf       1.000000
# Name: shelf, dtype: float64

# %%
df.corr()['weight'].sort_values()
# Out:
# fiber      -0.059863
# rating     -0.058047
# potass     -0.042764
# cups       -0.023145
# sugar       0.031597
# vitamins    0.052632
# sodium      0.086754
# protien     0.089300
# fat         0.107486
# shelf       0.225913
# carbo       0.284553
# calories    0.321588
# weight      1.000000
# Name: weight, dtype: float64

# %%
df.corr()['cups'].sort_values()
# Out:
# potass     -0.737368
# fiber      -0.698629
# shelf      -0.606019
# rating     -0.482326
# protien    -0.237194
# vitamins   -0.208307
# weight     -0.023145
# fat        -0.018907
# sodium      0.123130
# sugar       0.203370
# carbo       0.562574
# calories    0.579304
# cups        1.000000
# Name: cups, dtype: float64
